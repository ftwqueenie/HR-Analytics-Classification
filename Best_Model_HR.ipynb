# %%
# !pip install tpot

# %%
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import RepeatedStratifiedKFold
from tpot import TPOTClassifier

# load dataset

dataframe = read_csv('HR-Employee-Attrition.csv')
dataframe.head()
# Out:
# C:\Users\PERT\anaconda3\lib\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# ...

# %%
encode = LabelEncoder()
dataframe['BusinessTravel'] = encode.fit_transform(dataframe['BusinessTravel'])
dataframe['Department'] = encode.fit_transform(dataframe['Department'])
dataframe['EducationField'] = encode.fit_transform(dataframe['EducationField'])
dataframe['Attrition'] = encode.fit_transform(dataframe['Attrition'])
dataframe['Gender'] = encode.fit_transform(dataframe['Gender'])
dataframe['MaritalStatus'] = encode.fit_transform(dataframe['MaritalStatus'])
dataframe['OverTime'] = encode.fit_transform(dataframe['OverTime'])

# %%
# split into input and output elements
data = dataframe.values
# X = dataframe.drop('Customer_tag', axis=1)
X = dataframe[['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField','EnvironmentSatisfaction','Gender','JobInvolvement','JobLevel','JobSatisfaction','MaritalStatus','NumCompaniesWorked','OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StockOptionLevel','TotalWorkingYears','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
y = dataframe['Attrition']

# %%
# minimally prepare dataset
#X = X.astype('float32')
#y = LabelEncoder().fit_transform(y.astype('str'))

# define model evaluation
cv = RepeatedStratifiedKFold(n_splits=3, n_repeats=3, random_state=1)

# define search
model = TPOTClassifier(generations=3, population_size=10, cv=cv, scoring='accuracy', verbosity=2, random_state=1, n_jobs=-1)

# perform the search
model.fit(X, y)

# export the best model
model.export('HR_best_model.py')
# Out:
# ...
# Version 0.11.6.post1 of tpot is outdated. Version 0.11.6.post3 was released Monday December 14, 2020.
# ...
# Generation 1 - Current best internal CV score: 0.8668934240362812
#
# Generation 2 - Current best internal CV score: 0.8668934240362812
#
# Generation 3 - Current best internal CV score: 0.8668934240362812
#
# Best pipeline: LogisticRegression(MaxAbsScaler(input_matrix), C=10.0, dual=False, penalty=l2)
